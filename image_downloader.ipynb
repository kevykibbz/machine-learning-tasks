# %%
from bing_image_downloader import downloader

# %%
# Search query
query = 'dog' 

# Number of images to download
limit = 50  

downloader.download(query, limit=limit, output_dir='dataset/incoming_data', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [%] Downloading Images to E:\kevy\tasks\Clients\Abin\dataset\incoming_data\dog
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://4.bp.blogspot.com/-Dggam2dsVY8/U53tP5KuZ0I/AAAAAAAA-nE/_l0e93v91G8/s1600/cute-dog-pictures-025-022.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.tastefulspace.com/wp-content/uploads/2019/11/10-Amazing-Dog-Haircuts-from-Professional-Dog-Grooming-Services.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://3.bp.blogspot.com/-ZMpwMhvN1vc/VFZ330hGsBI/AAAAAAABN2A/92P-ImlDTmI/s1600/cute-dogs-045-18.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.guidedogs.org/wp-content/uploads/2018/01/Mobile.jpg
# [!] Issue getting: https://www.guidedogs.org/wp-content/uploads/2018/01/Mobile.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #4 from http://www.publicdomainpictures.net/pictures/170000/velka/dog-1463218026uIC.jpg
# ...
